# %%
import pandas as pd
import pymysql

# %%
df = pd.read_csv(r'C:\Users\avvij\AppData\Local\Temp\RED BUS\Final_df.csv')
df
# Out:
#                              Bus_name                            Bus_type  \
# 0                     Sri KVR Travels                   A/C Sleeper (2+1)
# 1                            FRESHBUS           Electric A/C Seater (2+2)
# 2                   IntrCity SmartBus          A/C Seater / Sleeper (2+1)
# 3      AdSri Durga Malleswari Travels                   A/C Sleeper (2+1)
# 4                   IntrCity SmartBus  Scania AC Multi Axle Sleeper (2+1)
# ...                               ...                                 ...
# 13445               Betrwanti Travels                   A/C Sleeper (2+1)
# 13446               Betrwanti Travels                   A/C Sleeper (2+1)
# 13447       MISHRA BANDHU BUS SERVICE          A/C Seater / Sleeper (2+1)
# 13448        KANAHAIYA TOUR & TRAVELS                    A/C Seater (2+3)
# 13449            Singh Tour & Travels                     AC Seater (2+2)
#
#       Start_time End_time Total_duration   Price  Seats_Available  Ratings  \
# ...

# %%
import mysql.connector

# %%
#sql connection
conn=pymysql.connect(
    host="localhost",
    user="root",
    password="rostervii123", 
    database="PROJECTS"
    
)
    
print("connection successfull")
my_cursor = conn.cursor()
# Out:
# connection successfull

# %%
   # Execute the SQL command to create a table
my_cursor.execute('''CREATE TABLE  REDBUS (
                          ID INT AUTO_INCREMENT PRIMARY KEY,
                          Bus_name TEXT,
                          Bus_type TEXT,
                          Start_time TIME,
                          End_time TIME,
                          Total_duration TEXT,
                          Price FLOAT,
                          Seats_Available INT,
                          Ratings FLOAT,
                          Route_link TEXT,
                          Route_name TEXT
                        )''')
print("Table created successfully!")
# Out:
# Table created successfully!

# %%
# SQL query to insert data into  table
insert_query = '''INSERT INTO REDBUS(
                    Bus_name,
                    Bus_type,
                    Start_time,
                    End_time,
                    Total_duration,
                    Price,
                    Seats_Available,
                    Ratings,
                    Route_link,
                    Route_name)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
data = df.values.tolist()

my_cursor.executemany(insert_query, data)

conn.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
